# %%
#Task 1

a=input("My name is: ")
b=input("His name is: ")
c=input("Relationship type:")
print (a,"and",b, "are "+c)
# Out:
# My name is: Alexander
# His name is: Zlatan
# Relationship type:friends
# Alexander and Zlatan are friends

# %%
#Task 2

x=input("Sentence: ")
print(x)
first_letters = []
all_words = x.split(" ")
for g in (all_words):
    print(g)
    first_letters.append(g[0])
        
    
print(f"First letters of '{x}' are: {first_letters}")
# Out:
# Sentence: Lego is awesome
# Lego is awesome
# Lego
# is
# awesome
# First letters of 'Lego is awesome' are: ['L', 'i', 'a']

# %%
#Task 3

def my_function(x, y):
    result=(x+" "+y)
    print (result.title())
def function_age(age):
    months = age*12
    result=(x+" "+y)
    print("Months: ", months)
    print("")
    print("Full name:",result.title(),"Age:", age, "years","(",months,"months)")
    print("")

for a in range (2):
    x, y=(input("First name:"), input("Last name:"))
    my_function(x, y)
    age = int(input("Your age:"))
    function_age(age)
# Out:
# First name:Alexander
# Last name:Zahariev
# Alexander Zahariev
# Your age:20
# Months:  240
#
# Full name: Alexander Zahariev Age: 20 years ( 240 months)
#
# First name:Rahil
# Last name:DAve
# Rahil Dave
# Your age:24
# Months:  288
#
# Full name: Rahil Dave Age: 24 years ( 288 months)

# %%
#Task 4 - Importing the dataset using pandas

import pandas as pd

df = pd.read_csv("Port_Data.csv", sep=";")
print(df)
# Out:
#      Unnamed: 0    Country      Port Name UN Code  Vessels in Port  \
# 0           429     Angola         LUANDA   AOLAD               55
# 1           170  Argentina   BUENOS AIRES   ARBUE              111
# 2           231  Argentina  MAR DEL PLATA   ARMDQ               88
# 3           315  Argentina       RECALADA       -               69
# 4           129  Australia         SYDNEY   AUSYD              139
# ..          ...        ...            ...     ...              ...
# 475          67    Vietnam      HAI PHONG   VNHPH              215
# 476          96    Vietnam    HO CHI MINH   VNSGN              163
# 477         175    Vietnam       VUNG TAU   VNVUT              109
# 478         336    Vietnam       NGHI SON   VNNGH               66
# 479         409    Vietnam   HON GAI ANCH       -               58
#
#      Departures(Last 24 Hours)  Arrivals(Last 24 Hours)  Expected Arrivals  \
# 0                           13                       11                 36
# ...

# %%
#Task 4 - correlations
df["Expected Arrivals"]. corr(df["Vessels in Port"])
# Out:
# 0.6387909874564407

# %%
#Task 5 - cleaning the data
df.pop("Unnamed: 0")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    480 non-null    object
#  1   Port Name                  480 non-null    object
#  2   UN Code                    468 non-null    object
#  3   Vessels in Port            480 non-null    int64
#  4   Departures(Last 24 Hours)  480 non-null    int64
#  5   Arrivals(Last 24 Hours)    480 non-null    int64
#  6   Expected Arrivals          480 non-null    int64
#  7   Total Ships                480 non-null    int64
#  8   Total ships in country     480 non-null    int64
#  9   Type                       480 non-null    object
#  10  Area Local                 480 non-null    object
#  11  Area Global                480 non-null    object
#  12  Also known as              480 non-null    object
# dtypes: int64(6), object(7)
# ...

# %%
df.pop("UN Code")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    480 non-null    object
#  1   Port Name                  480 non-null    object
#  2   Vessels in Port            480 non-null    int64
#  3   Departures(Last 24 Hours)  480 non-null    int64
#  4   Arrivals(Last 24 Hours)    480 non-null    int64
#  5   Expected Arrivals          480 non-null    int64
#  6   Total Ships                480 non-null    int64
#  7   Total ships in country     480 non-null    int64
#  8   Type                       480 non-null    object
#  9   Area Local                 480 non-null    object
#  10  Area Global                480 non-null    object
#  11  Also known as              480 non-null    object
# dtypes: int64(6), object(6)
# memory usage: 45.1+ KB
# None

# %%
dataset_modified = df
dataset_modified
# Out:
#        Country      Port Name  Vessels in Port  Departures(Last 24 Hours)  \
# 0       Angola         LUANDA               55                         13
# 1    Argentina   BUENOS AIRES              111                         37
# 2    Argentina  MAR DEL PLATA               88                          4
# 3    Argentina       RECALADA               69                         18
# 4    Australia         SYDNEY              139                        303
# ..         ...            ...              ...                        ...
# 475    Vietnam      HAI PHONG              215                         78
# 476    Vietnam    HO CHI MINH              163                         42
# 477    Vietnam       VUNG TAU              109                         98
# 478    Vietnam       NGHI SON               66                         17
# 479    Vietnam   HON GAI ANCH               58                         22
#
#      Arrivals(Last 24 Hours)  Expected Arrivals  Total Ships  \
# ...

# %%
#Task 6
import numpy as np

array1 = df['Vessels in Port'].to_numpy()
print(array1)

import numpy as np
arr = df['Vessels in Port'].to_numpy()
from numpy import random
from statistics import stdev
def randomcol_stats(x,v,a):
    x=random.choice(df['Vessels in Port'])
    print("In the Vessels in Port")
    print("A random number is", x)
    print("The Standard Deviation is % s"
                              %(stdev(arr)))
    print("The variance is", v)
    print("The average is", a)
    
v=np.var(arr)
a=np.average(arr)
randomcol_stats(x,v,a)
# Out:
# [  55  111   88   69  139  109   96   91   82   76   76   66   65   62
#    59   55   53  100   87   57   75   64  686  176   95   92   89   82
#   127  119   83   64   53   66  211   68   63   59   56   54   53   71
#  2420 1572 1529 1414 1112 1094 1064  945  868  863  731  716  662  638
#   602  562  550  534  465  460  416  403  387  364  340  332  321  319
#   312  300  283  278  271  271  266  265  262  255  255  243  231  231
#   229  228  226  206  197  191  181  173  171  171  170  169  167  158
#   158  156  151  150  149  148  144  141  140  140  139  130  128  126
#   121  120  119  119  118  118  113  113  113  109  108  102  100   99
#    96   96   93   93   92   88   86   86   86   86   84   82   82   80
#    79   78   78   75   73   72   72   71   68   68   67   66   64   63
#    63   62   62   60   60   59   56   55   51   51   92  137   66   62
#    59   57   53   52   59   79   80   56  129  119  107   96   88   79
# ...

# %%
#Task 7
import matplotlib
import matplotlib.pyplot as plt

import numpy as np
from matplotlib.pyplot import figure
figure(figsize=(20,5))

AG=np.array(df['Country'].to_numpy())
TS=np.array(df['Total ships in country'].to_numpy())



plt.bar(AG, TS)

plt.xticks(rotation=45, ha='right', fontsize=10)
plt.xlabel("Country",fontsize=15)
plt.ylabel("Total Ships",fontsize=15)

plt.title("Bar Chart of Total Ships in Country",fontsize=15)
plt.show()

#ha = horizontal allignment
